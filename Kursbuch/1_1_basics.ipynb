# %% [markdown]
# # Die Grundlagen
#
# ## Installation Python
#
# ### python.org
# [https://www.python.org/downloads/](https://www.python.org/downloads/)
#
# ### Webstore
# Wähle die letzte Version (vermutlich 3.9) und starte die Installation

# %% [markdown]
# ![webstore.png](attachment:webstore.png)

# %% [markdown]
# Wer keinen Zugriff zum Store oder Internet hat. Bekommt die letzte Version auf einen Usb-Stick
#
# _Wichtig_
# Bei der Installation, den Pfad setzen
#
# ![path.png](attachment:path.png)

# %% [markdown]
# _Pfad_(oder PATH) ist eine Systemvariable. Sie gibt den System bekannt in welchen Ordnern sich wichtige Programme befinden z.B. unser Python Interpreter

# %% [markdown]
# Wir starten jetzt eine Konsole :)

# %% [markdown]
# python + <kbd>Enter<kbd>

# %%
print("Hallo Welt")
# Out:
# Hallo Welt

# %%
5+6
# Out:
# 11

# %%
1/3
# Out:
# 0.3333333333333333

# %%
3 * (1/3)
# Out:
# 1.0

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
3/10
# Out:
# 0.3

# %%
5-3
# Out:
# 2

# %%
4**2
# Out:
# 16

# %%
40//7
# Out:
# 5

# %%
40/7
# Out:
# 5.714285714285714

# %% [markdown]
# ### Die Steuerzeichen
# #### Arithmetik
# + (Plus) -(Minus) *(Multiplikation) /(Division) %(Modulo) //(Ganzzahlige Division) **(Exponent, hoch)
#
# Rechenregeln wie aus der Mathematik
# * Punkt vor Steuerzeichen
# * Klammern
# * etc.

# %% [markdown]
# #Datentypen
# str: string,Zeichenkette , int: Integer , bool Boolean, float Gleitkommazahl
#
# ### Boolean
# True or False
# 1 oder 0
# Wahr oder Falsch
# Der einfachste Datentyp, eigentlich nur 1 Bit (nutzt jedoch in der Regel mindestens 8 Bit/1 Byte)
# Die Verwendung werden wir uns zu einen späteren Zeitpunkt anschauen.
# __False__ und __True__ sind hierbei vordefinierte Werte.
#
#
# ### Integer (Ganzzahl)
# z.b. 1,10,3434533
# Untergrenze -9.223.372.036.854.775.808 (~9 Trillarden)
# Obergrenze 9.223.372.036.854.775.807
# Direkt Abbildunge der BinaryWerte (zb. 0101 = 5)

# %%
type(2144783648+5)

# %% [markdown]
# ### Float
# Gleitkommazahl, rationale Zahlen (Brüche), irrationale Zahlen
# Kein Komma im englischsprachigen Bereich verwendet man den Punkt zur Trennung (und so auch in fast allen Programmiersprachen)
#
# z.b 0.1, 5.6, 3.141592653589793
# Ungenauigkeiten Aufgrund von Implementationsdetails
# [Gleitkommazahl](https://de.wikipedia.org/wiki/Gleitkommazahl)
#
# ### None
# None ist in anderen Sprachen auch als Null bekannt anders als 0 (das ein normaler Integer ist) ist None ein Platzhalter für Nichts.

# %% [markdown]
# ### String (Zeichenkette)
# Mit Zeichenketten kann man Texte sowie alle möglichen Symbole darstellen. Damit es vom Programmcode trennbar ist werden Hochkomma verwendet ähnlich wie bei der wörtliche Rede.
# "Hallo Welt" wäre so ein String.
# In einigen Programmiersprachen wird das doppelte Hochkomma "(C,C#,Java) in anderen das das einfach Hochkomma ' (Ruby,PHP). In Python ist beides erlaubt, jedoch nicht gemischt
# "Hallo" ok
# 'Hallo' ok
# 'Hallo" nope
# "Hallo' nope

# %% [markdown]
# ### Kombination von Datentypen
# Einige arithmetische Datentypen können in Kombination mit diversen Datentypen verwendet werden. Wobei das Ergebnis immer nur ein Datentyp sein kann. Bei Float und Integer macht das durchaus Sinn.

# %%
"Hallo"*5

# %%
"Hallo"+3

# %%
"Hallo"+"Welt"

# %%
"Hallo"+"Welt"*2

# %%
3 + 3.4

# %%
type(3 + 6.5)

# %% [markdown]
# # Variablen und Zuweisungen
# Abstrakter Behälter für einen Wert...

# %%
a = 5
b = 10
c = a+b
print(c)
type(c)

# %%
x = 2
y = 1/3*(x**3)-1/4*(x**2)+3*x+17 # 1/3 x³-1/4x²+3x+17
print(y)

# %% [markdown]
# ## Namensregeln
# * Namen von Variablen dürfen aus Buchstaben, Ziffern und dem Unterstrich bestehen
# z.B. wagen , SiGi1234, vhs_berchtesgaden
# * Das erste Zeichen darf keine Ziffer sein
# * Groß und Kleinschreibung wird unterschieden
# * Keine Umlaute (ä,ö,ü)
# * keine reservierten Wörter (z.b. break, continue, def, try) [Liste](https://www.w3schools.com/python/python_ref_keywords.asp)

# %% [markdown]
# Welch dieser Wörter sind valide Variablenamen?
# hallo
# _12_bu
# try
# Continue
# Über
# unter
# _
# 101_vhs

# %% [markdown]
# ### Styles
# Entwickler mögen eine durchgangige Regeln/Styles zum benennen von Variablen.
# Einige bekannte sind
# CamelCase
# snakeCase
# under_score
# Hier gibt es keine Vorschriften, zur besseren Lesbarkeit ist es aber ratsam sich auf einen Stil festzulegen. Bei einem Stil könnnen auch mehrere Stile vermischt werden z.b. Variablen mit snakeCase, Funktionen mit CamelCase etc.
# #### __WICHTIG__
# Wir geben unseren Variablen richtige Namen die ihre Verwenden beschreiben z.B.
# ergebnis = 5+3
#
# Namen wie a,b oder z sind zwar am Anfang noch eindeutig, jedoch verlieren im Laufe der Zeit ihre Bedeutung.
# * Benenne Variablen so, dass ein anderer Entwickler weiß was damit gemacht wird
# * Benenne Variablen so, dass dir in 2 Jahren ihre Verwendung noch klar ist.

# %% [markdown]
# ### Zuweisungen und None
# Variablen muss vor der Verwendung ein Wert zugewiesen werden.

# %%
abc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-03cfd743661f> in <module>
# ----> 1 abc
#
# NameError: name 'abc' is not defined

# %%
abc = None

# %%
abc = "MyValue"

# %%
# Funktionen 
* Ist ein Konstrukt zur Wiederverwendung eines Programmteils (Wikipedia)
* Ein Abbildung einer Beziehung f(x)= x²

Nehmen wir das Beispiel von vorher:

# %%
x = 2
y = 1/3*(x**3)-1/4*(x*2)+3*x+17 # 1/3 x³-1/4x²+3x+17
print(y)
# Out:
# 24.666666666666664

# %% [markdown]
# Es wäre etwas mühsam die Zeile y = 1/3(x**3)-1/4(x*2)+3x+17 immer wieder für jedes erdenklich x zu schreiben deswegen können wir mittels def ein Funktion definieren, der Syntax hier ist wie folgt:

# %%
def funktions_name (parameter1, paramter2):
    print("code innerhalb der funktion wird eingerück")#einrückung um eine einheit (4*Space oder 1*Tab)

def begruessung(name):
    print("Hallo " + name)

begruessung("Finja")
begruessung("Tina")
# Out:
# Hallo Finja
# Hallo Tina

# %% [markdown]
# Variablen die einer Funktion übergeben werden nennt man Parameter.Einer Funktion können beliebig viele Parameter . Sie gelten innerhalb der Funktion

# %% [markdown]
# ### Rückgabewerte
# Einige Funktionen liefern ein Ergebnis, dies wird mittels des Keyword __return__ gemacht def eine_funktion(x): ergebnis = 1/3(x**3)-1/4(x*2)+3x+17 return ergebnis Das Ergbnis muss nicht zwingend in ein lokale Variable gespeichert werden (lokal Varibalen sind Variablen innerhalb der Funktion) mehr dazu später :)

# %%
def eine_funktion(x):
    ergebnis = 1/3*(x**3)-1/4*(x*2)+3*x+17
    return ergebnis
mein_ergebnis = eine_funktion(5)
print(mein_ergebnis)
print(ergebnis)##??!!!

# %% [markdown]
# ### Typehinting
# Python ist dynamisch typisiert dh. Typen müssen während des programmierens nicht deklariert werden (wie in anderen Programmiersprachen) und werden erst zur Laufzeit ermittelt. Als Hilfestellung für Entwickler können(sollten) Typehints verwendet werden.

# %%
def halbiere(a:int)->float:
    return a/2.0

def als_string(a:int)->str:
    return str(a)

# %% [markdown]
# ### Kommentare
# Kommentare sind nützlich um anderen Entwicklern Hinweise zu hinterlassen. So kann die Absicht hinter dem Code erklärt werden, wenn die Bennennung der Variablen/Funktionen als Erklärung allein nicht ausreicht.

# %%
def halbiere(a:int)->int:
    '''Achtung ganzzahlige Division, dieses Kommentar kann von andere Tools verwendet werden um es als Hilfe anzuzeigen
    Dies Kommentar kann mehrzeilig sein. Beachte die Einrückungen bei Funktionen. 
    '''
    return a//2 # // macht eine ganzzahlige Division, mit # kann eine Kommentar innerhalb eines Programmes erzeug werden
